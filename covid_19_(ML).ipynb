# %% [markdown]
# <a href="https://colab.research.google.com/github/Neerav21/covid-19-spread-analysis/blob/main/covid_19_(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
covid = pd.read_csv('/content/drive/MyDrive/covid_TAN.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,2,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Having a glance at some of the records
covid.head()
# Out:
#   iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 0      ABW    Aruba  ...                    NaN                     NaN
# 1      ABW    Aruba  ...                    NaN                     NaN
# 2      ABW    Aruba  ...                    NaN                     NaN
# 3      ABW    Aruba  ...                    NaN                     NaN
# 4      ABW    Aruba  ...                    NaN                     NaN
#
# [5 rows x 32 columns]

# %%
#Looking at the shape
covid.shape
# Out:
# (19496, 32)

# %%
covid.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
#Looking at the different locations
covid["location"].value_counts()
# Out:
# Greece                             146
# Croatia                            146
# Denmark                            146
# Canada                             146
# China                              146
#                                   ...
# Burundi                             54
# Bonaire Sint Eustatius and Saba     53
# Falkland Islands                    51
# Western Sahara                      29
# Comoros                             23
# Name: location, Length: 93, dtype: int64

# %%
#Checking if columns have null values
covid.isna().any()
# Out:
# iso_code                           True
# location                           True
# date                               True
# total_cases                        True
# new_cases                          True
# total_deaths                       True
# new_deaths                         True
# total_cases_per_million            True
# new_cases_per_million              True
# total_deaths_per_million           True
# new_deaths_per_million             True
# total_tests                        True
# new_tests                          True
# total_tests_per_thousand           True
# new_tests_per_thousand             True
# new_tests_smoothed                 True
# new_tests_smoothed_per_thousand    True
# tests_units                        True
# stringency_index                   True
# population                         True
# population_density                 True
# median_age                         True
# aged_65_older                      True
# aged_70_older                      True
# gdp_per_capita                     True
# extreme_poverty                    True
# cvd_death_rate                     True
# diabetes_prevalence                True
# female_smokers                     True
# male_smokers                       True
# handwashing_facilities             True
# hospital_beds_per_100k             True
# dtype: bool

# %%
#Getting the sum of null values across each column
covid.isna().sum()
# Out:
# iso_code                           10827
# location                           10827
# date                               10827
# total_cases                        10827
# new_cases                          10827
# total_deaths                       10827
# new_deaths                         10827
# total_cases_per_million            10979
# new_cases_per_million              10979
# total_deaths_per_million           10979
# new_deaths_per_million             10979
# total_tests                        17524
# new_tests                          17747
# total_tests_per_thousand           17524
# new_tests_per_thousand             17747
# new_tests_smoothed                 17197
# new_tests_smoothed_per_thousand    17197
# tests_units                        16955
# stringency_index                   12599
# population                         10827
# population_density                 11085
# median_age                         11586
# aged_65_older                      11615
# aged_70_older                      11586
# gdp_per_capita                     11620
# extreme_poverty                    14359
# cvd_death_rate                     11583
# diabetes_prevalence                11282
# female_smokers                     13138
# male_smokers                       13210
# handwashing_facilities             16245
# hospital_beds_per_100k             12192
# dtype: int64

# %%
#Getting the cases in India
india_case=covid[covid["location"]=="India"]

# %%
india_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8379      IND    India  ...                  59.55                    0.53
# 8380      IND    India  ...                  59.55                    0.53
# 8381      IND    India  ...                  59.55                    0.53
# 8382      IND    India  ...                  59.55                    0.53
# 8383      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
india_case.tail()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8519      IND    India  ...                  59.55                    0.53
# 8520      IND    India  ...                  59.55                    0.53
# 8521      IND    India  ...                  59.55                    0.53
# 8522      IND    India  ...                  59.55                    0.53
# 8523      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total cases per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
#Making a dataframe for last 5 days
india_last_5_days=india_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(3,3)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
#Total tests per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
#Total tests in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
#Brazil Case
brazil_case=covid[covid["location"]=="Brazil"]
brazil_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2510      BRA   Brazil  ...                    NaN                     2.2
# 2511      BRA   Brazil  ...                    NaN                     2.2
# 2512      BRA   Brazil  ...                    NaN                     2.2
# 2513      BRA   Brazil  ...                    NaN                     2.2
# 2514      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
brazil_case.tail()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 2651      BRA   Brazil  ...                    NaN                     2.2
# 2652      BRA   Brazil  ...                    NaN                     2.2
# 2653      BRA   Brazil  ...                    NaN                     2.2
# 2654      BRA   Brazil  ...                    NaN                     2.2
# 2655      BRA   Brazil  ...                    NaN                     2.2
#
# [5 rows x 32 columns]

# %%
#Making a dataframe for brazil for last 5 days
brazil_last_5_days=brazil_case.tail()

# %%
#Total cases in last 5 days
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=brazil_last_5_days)
plt.show()

# %%
#Understanding cases of India, China and Japan
india_japan_china=covid[(covid["location"] =="India") | (covid["location"] =="China") | (covid["location"]=="Japan")]

# %%
#Plotting growth of cases across China, India and Japan
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=india_japan_china,hue="date")
plt.show()

# %%
#Understanding cases of germany and spain
germany_spain=covid[(covid["location"] =="Germany") | (covid["location"] =="Spain")]

# %%
#Plotting growth of cases across Germany and Spain
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="location",y="total_cases",data=germany_spain,hue="date")
plt.show()

# %%
#Getting latest data
last_day_cases=covid[covid["date"]=="2020-05-24"]
last_day_cases
# Out:
# Empty DataFrame
# Columns: [iso_code, location, date, total_cases, new_cases, total_deaths, new_deaths, total_cases_per_million, new_cases_per_million, total_deaths_per_million, new_deaths_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, new_tests_smoothed, new_tests_smoothed_per_thousand, tests_units, stringency_index, population, population_density, median_age, aged_65_older, aged_70_older, gdp_per_capita, extreme_poverty, cvd_death_rate, diabetes_prevalence, female_smokers, male_smokers, handwashing_facilities, hospital_beds_per_100k]
# Index: []

# %%
#Sorting data w.r.t total_cases
max_cases_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_cases_country
# Out:
# Empty DataFrame
# Columns: [iso_code, location, date, total_cases, new_cases, total_deaths, new_deaths, total_cases_per_million, new_cases_per_million, total_deaths_per_million, new_deaths_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, new_tests_smoothed, new_tests_smoothed_per_thousand, tests_units, stringency_index, population, population_density, median_age, aged_65_older, aged_70_older, gdp_per_capita, extreme_poverty, cvd_death_rate, diabetes_prevalence, female_smokers, male_smokers, handwashing_facilities, hospital_beds_per_100k]
# Index: []

# %%
#Top 5 countries with maximum cases
max_cases_country[1:6]
# Out:
# Empty DataFrame
# Columns: [iso_code, location, date, total_cases, new_cases, total_deaths, new_deaths, total_cases_per_million, new_cases_per_million, total_deaths_per_million, new_deaths_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, new_tests_smoothed, new_tests_smoothed_per_thousand, tests_units, stringency_index, population, population_density, median_age, aged_65_older, aged_70_older, gdp_per_capita, extreme_poverty, cvd_death_rate, diabetes_prevalence, female_smokers, male_smokers, handwashing_facilities, hospital_beds_per_100k]
# Index: []

# %%
#Making bar-plot for countries with top cases
sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a0c5093ff7a2> in <module>()
#       1 #Making bar-plot for countries with top cases
# ----> 2 sns.barplot(x="location",y="total_cases",data=max_cases_country[1:6],hue="location")
#       3 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
#    3187     if ax is None:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
# -> 1586         self.establish_colors(color, palette, saturation)
#    1587         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1588
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     317         # Determine the gray color to use for the lines framing the plot
#     318         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 319         lum = min(light_vals) * .6
#     320         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     321
#
# ValueError: min() arg is an empty sequence

# %%
india_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8379      IND    India  ...                  59.55                    0.53
# 8380      IND    India  ...                  59.55                    0.53
# 8381      IND    India  ...                  59.55                    0.53
# 8382      IND    India  ...                  59.55                    0.53
# 8383      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
#converting string date to date-time
import datetime as dt
india_case['date'] = pd.to_datetime(india_case['date'])
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8379      IND    India  ...                  59.55                    0.53
# 8380      IND    India  ...                  59.55                    0.53
# 8381      IND    India  ...                  59.55                    0.53
# 8382      IND    India  ...                  59.55                    0.53
# 8383      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
india_case.head()
# Out:
#      iso_code location  ... handwashing_facilities  hospital_beds_per_100k
# 8379      IND    India  ...                  59.55                    0.53
# 8380      IND    India  ...                  59.55                    0.53
# 8381      IND    India  ...                  59.55                    0.53
# 8382      IND    India  ...                  59.55                    0.53
# 8383      IND    India  ...                  59.55                    0.53
#
# [5 rows x 32 columns]

# %%
#converting date-time to ordinal
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      iso_code location  ...  handwashing_facilities  hospital_beds_per_100k
# 8379      IND    India  ...                   59.55                    0.53
# 8380      IND    India  ...                   59.55                    0.53
# 8381      IND    India  ...                   59.55                    0.53
# 8382      IND    India  ...                   59.55                    0.53
# 8383      IND    India  ...                   59.55                    0.53
#
# [5 rows x 32 columns]

# %%
#getting dependent variable and inpedent variable
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %%
#lr = LinearRegression()
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

# %%
import numpy as np
#lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))


#Train the model using the training sets
clf.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
india_case.tail()

# %%
#y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
y_pred=clf.predict(np.array(x_test).reshape(-1,1)) ## prediction using SVM

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)

# %%
lr.predict(np.array([[737573]]))
